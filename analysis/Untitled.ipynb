# %%
import pandas as pd
import plotly.express as px

# %%
df_apt = pd.read_excel('../apt_get/Final_Data_Apt.xlsx')
# df_apt.head()
# Out:
# /home/amul/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning:
#
# Columns (2,8,17,31,35,41,42) have mixed types.Specify dtype option on import or set low_memory=False.

# %%
df_apt.columns
# Out:
# Index(['Package', 'Ruby-Versions', 'Gstreamer-Uri-Sinks', 'Ghc-Package',
#        'Priority', 'Depends', 'Section', 'Gstreamer-Elements', 'Build-Depends',
#        'Breaks', 'Pre-Depends', 'Origin', 'APT-Manual-Installed', 'Supported',
#        'Task', 'Original-Maintainer', 'Suggests', 'Python-Version',
#        'Build-Essential', 'Download-Size', 'Version', 'Replaces', 'Provides',
#        'Gstreamer-Encoders', 'Gstreamer-Decoders', 'Enhances', 'Recommends',
#        'Python3-Version', 'Build-Ids', 'APT-Sources', 'Gstreamer-Uri-Sources',
#        'Modaliases', 'Installed-Size', 'Bugs', 'Conflicts', 'Efi-Vendor',
#        'Gstreamer-Version', 'Source', 'Description', 'Homepage',
#        'Phased-Update-Percentage', 'Package-Type', 'Xul-Appid', 'Built-Using',
#        'Tag', 'Python-Egg-Name', 'Essential', 'Lua-Versions',
#        'Postgresql-Version', 'State', 'Maintainer'],
#       dtype='object')

# %%
df_macports = pd.read_csv('../macports/macports_data.tsv', sep='\t')

# %%
df_macports.columns
# Out:
# Index(['name', 'portdir', 'version', 'license', 'platforms',
#        'dependencies|0|type', 'dependencies|0|ports|0', 'description',
#        'long_description', 'categories|0', 'homepage', 'active',
#        'dependencies|1|type', 'dependencies|1|ports|0',
#        'maintainers|0|ports_count', 'maintainers|0|name', 'depends_on|0|type',
#        'depends_on|0|ports|0', 'dependencies|0|ports|1',
#        'maintainers|0|github', 'dependencies|1|ports|1', 'variants|0',
#        'categories|1', 'dependencies|1|ports|2', 'depends_on|0|ports|1',
#        'dependencies|1|ports|3', 'dependencies|0|ports|2',
#        'dependencies|2|type', 'dependencies|2|ports|0', 'variants|1'],
#       dtype='object')

# %%
df_choco = pd.read_excel('../choco/Final_Data_Choco.xlsx')

# %%
df_choco.columns
# Out:
# Index(['package_name', 'Number of Downloads', 'version', 'tags',
#        'Release Notes', 'title', 'Package testing status',
#        'Chocolatey Package Source', 'description', '_x0007_ Documentation',
#        'published', 'Mailing List', 'Issues', 'Documentation', 'approved_by',
#        'Software License', 'approved_on', 'Details of Release Notes',
#        'Package Checksum', 'Description', 'Downloads for this version',
#        'Summary', '**Fixed Issues', 'Software Source', 'Software Site',
#        'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28',
#        'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32',
#        'Unnamed: 33', 'Unnamed: 34', 'Unnamed: 35', 'Unnamed: 36',
#        'Unnamed: 37', 'Unnamed: 38', 'Unnamed: 39', 'Unnamed: 40'],
#       dtype='object')

# %%
df_brew = pd.read_excel('../brew/brew_data.xlsx')
df_brew.columns
# Out:
# Index(['name', 'full_name', 'tap', 'aliases', 'versioned_formulae', 'desc',
#        'homepage', 'versions|stable', 'versions|bottle', 'urls|stable|url',
#        'revision', 'version_scheme', 'keg_only', 'bottle_disabled', 'options',
#        'build_dependencies', 'dependencies', 'recommended_dependencies',
#        'optional_dependencies', 'uses_from_macos', 'requirements',
#        'conflicts_with', 'installed', 'pinned', 'outdated', 'deprecated',
#        'disabled', 'generated_date', 'bottle|stable|rebuild',
#        'bottle|stable|root_url', 'bottle|stable|files|catalina|cellar',
#        'bottle|stable|files|catalina|url',
#        'bottle|stable|files|catalina|sha256',
#        'bottle|stable|files|mojave|cellar', 'bottle|stable|files|mojave|url',
#        'bottle|stable|files|mojave|sha256',
#        'bottle|stable|files|big_sur|cellar', 'bottle|stable|files|big_sur|url',
#        'bottle|stable|files|big_sur|sha256', 'license'],
#       dtype='object')

# %%
def analysis(df, column):
    df1 = df[column].to_frame()
    freq = df1.stack().value_counts().to_frame().reset_index()
    freq.columns = ['Developer', 'Packages Developed']
#     top_freq = pd.DataFrame(list(zip([freq['developer'][0], 'Others'], [freq['count'][0], freq['count'][1:].sum()])), columns=['Developer', 'Packages Developed'])
#     print(freq['count'][1:].sum(), freq['count'][0])
#     print(top_freq.head(2))
#     print(freq.columns)
#     fig = px.pie(top_freq, values='Packages Developed', names='Developer', title='APT: Developers vs Package Developed',
#                 color_discrete_sequence=px.colors.sequential.RdBu)
#     fig.show()

    freq = freq[0:]
    print('Top 10 Developers (Macports)')
    fig = px.pie(freq.head(10), values='Packages Developed', names='Developer', title='MacPorts: Top 10 Developers',
                color_discrete_sequence=px.colors.sequential.RdBu)
    fig.show()

analysis(df_macports, 'maintainers|0|name')
# Out:
# Top 10 Developers (Macports)
# ...

# %%
import numpy as np
import pandas as pd
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

import matplotlib.pyplot as plt
% matplotlib inline
# Out:
# UsageError: Line magic function `%` not found.

# %%
# def transform_format(val):
#     if val == 0:
#         return 255
#     else:
#         return val
    
# linux_logo = np.array(Image.open("./linux_logo.png"))
# transformed_linux_logo = np.ndarray((linux_logo.shape[0],linux_logo.shape[1]), np.int32)

# for i in range(len(linux_logo)):
#     transformed_linux_logo[i] = list(map(transform_format, linux_logo[i]))
    
# print(transformed_linux_logo)
# Out:
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]

# %%
stopwords = set(STOPWORDS)
stopwords.update(['package', 'library', 'program', 'support', 'documentation',
                 'contain', 'data', 'using', 'use', 'provide', 'provides', 'file', 'used',
                 'used', 'contains', 'tool', 'function', 'used', 'module', 'files', 'system',
                 'development', 'application', 'format', 'api', 'simple', 'information', 
                 'interface', 'development', 'system', 'allow', 'version', 'plugin', 'based',
                 'libraries', 'include', 'based', 'user', 'functions', 'tools', 'applications',
                 'includes', 'supports','libraries', 'feature', 'includes', 'available',
                 'features', 'easy', 'command', 'line', 'applications', 'set', 'nan',
                 'implementation', 'Implementation', 'will', 'allows', 'programming',
                 'language', 'many', 'packages', 'software', 'platform', 'code', 'source', 'open',
                 'install', 'https', 'chocolatey', 'choco', 'parameter', 'example', 'please'])

# text = " ".join(str(review) for review in df_apt['Description'])
# text = " ".join(str(review) for review in df_brew['desc'])
# text = " ".join(str(review) for review in df_choco['description'])
text = " ".join(str(review) for review in df_macports['long_description'])


def generate_basic_wordcloud(data, title):
    cloud = WordCloud(width=400,
                      height=330,
                      max_words=300,
                      colormap='tab20c',
                      stopwords=stopwords,
                      collocations=False).generate_from_text(data)
    plt.figure(figsize=(10,8))
    plt.imshow(cloud)
    plt.axis('off')
    plt.title(title, fontsize=13)
    plt.savefig('./stopwords_figures/macports.jpg')
    plt.show()
    
generate_basic_wordcloud(text, 'macports: Description')

# wordcloud = WordCloud(background_color="white", max_words=10, mask=transfo
# rmed_linux_logo,
#                stopwords=stopwords, contour_width=3, contour_color='firebrick').generate(text)

# # Create and generate a word cloud image:
# wordcloud = WordCloud(stopwords=stopwords, 
#                       max_font_size=50, max_words=100, 
#                       background_color="white").generate(text)

# Display the generated image:
# plt.imshow(wordcloud, interpolation='bilinear')
# plt.axis("off")
# plt.show()

# %%
import json
with open('../apt_get/processed_data.json', 'r') as f:
    data_apt = json.load(f)

# %%
import string
def clean(text):
    text = text.translate(str.maketrans('', '', string.punctuation))
#     text = text.replace('#', '')
#     text = text.replace('*', '')
#     text = text.replace('.', '')
    return text
    
def generate_N_grams(text,ngram=1):
    words=[word for word in text.split() if word not in set(stopwords)]  
#     print("Sentence after removing stopwords:",words)
    temp=zip(*[words[i:] for i in range(0,ngram)])
    ans=[' '.join(ngram) for ngram in temp]
    return ans

from collections import Counter
grams = [Counter() for x in range(10)]
no_desc = 0
print(len(data_apt.keys()))
for _, details in data_apt.items():
# for text in df_apt['Description']:
    for j in range(1, 10):
        if 'Description' in details:
            for word in generate_N_grams(clean(str(details['Description'])), j):
                grams[j][word] += 1
        else:
            no_desc += 1
# Out:
# 67681

# %%
from collections import Counter
grams_choco = [Counter() for x in range(10)]
for text in df_choco['description']:
    for j in range(1, 10):
        for word in generate_N_grams(str(text), j):
            grams_choco[j][word] += 1

# %%
haskel = 0
python = 0
print(df_apt.shape)
for text in df_apt['Description']:
    text = str(text)
    if 'haskel'.lower() in text.lower():
        haskel += 1
    if 'python'.lower() in text.lower():
        python += 1

print(f"python: {python}, haskel: {haskel}")
# Out:
# (38504, 51)
# python: 2417, haskel: 2088

# %%
k = 7
grams[k].most_common(20)
# Out:
# [('This Haskell compiled profiling See httpwwwhaskellorg Haskell', 611),
#  ('fullfeatured office productivity suite near dropin replacement', 187),
#  ('office productivity suite near dropin replacement MicrosoftR', 187),
#  ('productivity suite near dropin replacement MicrosoftR Office', 187),
#  ('suite near dropin replacement MicrosoftR Office This', 180),
#  ('bulk translation updated seldom This frequent translation', 166),
#  ('translation updated seldom This frequent translation updates', 166),
#  ('LibreOffice fullfeatured office productivity suite near dropin', 165),
#  ('Mono running developing ECMAISO Standards Mono effort', 160),
#  ('running developing ECMAISO Standards Mono effort led', 160),
#  ('Mono complete CLR Common Language Runtime including', 160),
#  ('complete CLR Common Language Runtime including compiler', 160),
#  ('CLR Common Language Runtime including compiler runtime', 160),
#  ('Common Language Runtime including compiler runtime produce', 160),
# ...
